# %%
import pandas as pd

df = pd.read_csv("../data/raw/points/2024-usopen-points.csv")

matches = pd.read_csv("../data/raw/match/2024-usopen-matches.csv")
